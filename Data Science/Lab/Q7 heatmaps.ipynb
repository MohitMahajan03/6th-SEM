# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'X1' : np.random.randn(10),
    'X2' : np.random.randn(10),
    'X3' : np.random.randn(10),
    'X4' : np.random.randn(10)
}
data
# Out:
# {'X1': array([-0.11275293, -0.52651649, -0.66502032,  1.32698195,  0.56147479,
#          1.125372  , -0.46613433, -1.55595515, -0.30177212,  0.63061789]),
#  'X2': array([ 2.15547285, -0.77282393, -0.03431649,  1.04977594,  1.1718576 ,
#         -0.72673048, -0.11553687,  1.50348923,  2.27982948,  0.44630033]),
#  'X3': array([ 0.82203413, -1.56830441, -1.82615438,  1.55877965,  0.90038783,
#         -0.51420865,  0.76739068,  0.5744406 ,  0.7158805 ,  2.21750486]),
#  'X4': array([ 0.74764319,  0.24063023, -1.74981469, -0.48401603,  0.88178371,
#          0.63359399,  0.22532965,  0.10878082, -0.47073623,  0.6530471 ])}

# %%
df = pd.DataFrame(data)
df['X1'][1] = 5
df
# Out:
#          X1        X2        X3        X4
# 0 -0.112753  2.155473  0.822034  0.747643
# 1  5.000000 -0.772824 -1.568304  0.240630
# 2 -0.665020 -0.034316 -1.826154 -1.749815
# 3  1.326982  1.049776  1.558780 -0.484016
# 4  0.561475  1.171858  0.900388  0.881784
# 5  1.125372 -0.726730 -0.514209  0.633594
# 6 -0.466134 -0.115537  0.767391  0.225330
# 7 -1.555955  1.503489  0.574441  0.108781
# 8 -0.301772  2.279829  0.715880 -0.470736
# 9  0.630618  0.446300  2.217505  0.653047

# %%
sns.heatmap(df.corr(), cmap='coolwarm', annot = True)
# Out:
# <Axes: >

# %%
x = df['X1']
x.plot(kind = 'line')
# Out:
# <Axes: >

# %%
# Showing Outliers

df.plot(kind = 'box')
# Out:
# <Axes: >
