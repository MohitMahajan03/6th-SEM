# %%
import pandas as pd

# %% [markdown]
# ### Reading CSV and Creating Dataframes

# %%
df = pd.read_csv("IPL/match_data.csv")
# df.dropna(inplace=True)
df
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_9980\868225583.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("IPL/match_data.csv")
#         match_id   season  start_date                             venue
# 0        1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad  \
# 1        1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 2        1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 3        1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 4        1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# ...          ...      ...         ...                               ...
# 243812    335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 243813    335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 243814    335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# ...

# %% [markdown]
# ### Constructing Series

# %%
matchid = pd.Series(df['match_id'])
print(matchid)
bow_team = pd.Series(df['bowling_team'])
print(bow_team)
# Out:
# 0         1370353
# 1         1370353
# 2         1370353
# 3         1370353
# 4         1370353
#            ...
# 243812     335982
# 243813     335982
# 243814     335982
# 243815     335982
# 243816     335982
# Name: match_id, Length: 243817, dtype: int64
# 0           Chennai Super Kings
# 1           Chennai Super Kings
# 2           Chennai Super Kings
# 3           Chennai Super Kings
# 4           Chennai Super Kings
#                   ...
# 243812    Kolkata Knight Riders
# 243813    Kolkata Knight Riders
# 243814    Kolkata Knight Riders
# 243815    Kolkata Knight Riders
# 243816    Kolkata Knight Riders
# Name: bowling_team, Length: 243817, dtype: object

# %% [markdown]
# ## Sorting in Data Frames

# %% [markdown]
# ### Sorting by index

# %%
df.sort_index()
# Out:
#         match_id   season  start_date                             venue
# 0        1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad  \
# 1        1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 2        1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 3        1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# 4        1370353     2023  2023-05-29  Narendra Modi Stadium, Ahmedabad
# ...          ...      ...         ...                               ...
# 243812    335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 243813    335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 243814    335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 243815    335982  2007/08  2008-04-18             M Chinnaswamy Stadium
# 243816    335982  2007/08  2008-04-18             M Chinnaswamy Stadium
#
#         innings  ball                 batting_team           bowling_team
# ...

# %% [markdown]
# ### Sorting based on values

# %%
df.sort_values(by= 'innings', ascending= False)
# Out:
#         match_id   season  start_date
# 56369    1216517  2020/21  2020-10-18  \
# 56368    1216517  2020/21  2020-10-18
# 56367    1216517  2020/21  2020-10-18
# 56366    1216517  2020/21  2020-10-18
# 56359    1216517  2020/21  2020-10-18
# ...          ...      ...         ...
# 107278    981019     2016  2016-05-29
# 107279    981019     2016  2016-05-29
# 107280    981019     2016  2016-05-29
# 107281    981019     2016  2016-05-29
# 121908    829819     2015  2015-05-20
#
#                                           venue  innings  ball
# 56369       Dubai International Cricket Stadium        6   0.4  \
# 56368       Dubai International Cricket Stadium        6   0.3
# 56367       Dubai International Cricket Stadium        6   0.2
# 56366       Dubai International Cricket Stadium        6   0.1
# 56359       Dubai International Cricket Stadium        5   0.2
# ...                                         ...      ...   ...
# ...

# %%
df = pd.read_csv('IPL/match_info_data.csv')
df
df.plot.scatter(x = 'toss_decision', y='win_by_runs')
# Out:
# <Axes: xlabel='toss_decision', ylabel='win_by_runs'>

# %%
df = pd.read_csv("student/students - Sheet1.csv")
df
# Out:
#           id first_name last_name date_of_birth               ethnicity
# 0   111111.0       John       Doe       01/2000                Hispanic  \
# 1   111112.0       Jane     Smith       05/2001                Hispanic
# 2   111113.0      Sarah    Thomas       21/2002                Hispanic
# 3   111114.0      Frank     Brown       13/2002  Race/ethnicity unknown
# 4   111115.0       Mike     Davis       31/2001                   White
# 5   111116.0   Jennifer    Wilson       01/2002                   Asian
# 6   111117.0    Jessica    Garcia       01/2000                   White
# 7   111118.0       Fred     Clark       17/1999                Hispanic
# 8   111119.0        Bob     Lopez       04/1998                   White
# 9        NaN        NaN       NaN           NaN                     NaN
# 10       NaN        NaN       NaN           NaN                     NaN
# 11       NaN        NaN       NaN           NaN                     NaN
# ...

# %% [markdown]
# ## Group By function

# %%
gender = df.groupby(by='gender').sum()
gender
# Out:
#               id              first_name                   last_name
# gender
# F       555581.0  JaneMikeJessicaFredBob  SmithDavisGarciaClarkLopez  \
# M       444454.0  JohnSarahFrankJennifer        DoeThomasBrownWilson
#
#                               date_of_birth
# gender
# F       05/200131/200101/200017/199904/1998  \
# M              01/200021/200213/200201/2002
#
#                                           ethnicity
# gender
# F                   HispanicWhiteWhiteHispanicWhite  \
# M       HispanicHispanicRace/ethnicity unknownAsian
#
#                             status
# gender
# F       TRANSFERFTFTFTFTFTGRADFTFT  \
# M               FTFTFTFTFTTRANSFER
#
#                                 entry_academic_period  exclusion_type
# gender
# F       Fall 2006Fall 2007Fall 2007Fall 2010Fall 2007             0.0  \
# M                Fall 2008Fall 2006Fall 2006Fall 2006             0.0
#
#         act_composite  act_math  ... sat_reading  hs_gpa
# ...

# %%
ethnicity = df.groupby(by='ethnicity').sum()
ethnicity
# Out:
#                               id         first_name            last_name
# ethnicity
# Asian                   111116.0           Jennifer               Wilson  \
# Hispanic                444454.0  JohnJaneSarahFred  DoeSmithThomasClark
# Race/ethnicity unknown  111114.0              Frank                Brown
# White                   333351.0     MikeJessicaBob     DavisGarciaLopez
#
#                                        date_of_birth gender
# ethnicity
# Asian                                        01/2002      M  \
# Hispanic                01/200005/200121/200217/1999   MFMF
# Race/ethnicity unknown                       13/2002      M
# White                          31/200101/200004/1998    FFF
#
#                                       status
# ethnicity
# Asian                               TRANSFER  \
# Hispanic                FTTRANSFERFTFTFTGRAD
# Race/ethnicity unknown                  FTFT
# White                           FTFTFTFTFTFT
#
# ...

# %%
status = df.groupby(by='status').sum()
status
# Out:
#                 id                first_name                    last_name
# status
# FT        111111.0                      John                          Doe  \
# FTFT      555578.0  SarahFrankMikeJessicaBob  ThomasBrownDavisGarciaLopez
# FTGRAD    111118.0                      Fred                        Clark
# TRANSFER  222228.0              JaneJennifer                  SmithWilson
#
#                                 date_of_birth
# status
# FT                                    01/2000  \
# FTFT      21/200213/200231/200101/200004/1998
# FTGRAD                                17/1999
# TRANSFER                       05/200101/2002
#
#                                               ethnicity gender
# status
# FT                                             Hispanic      M  \
# FTFT      HispanicRace/ethnicity unknownWhiteWhiteWhite  MMFFF
# FTGRAD                                         Hispanic      F
# TRANSFER                                  HispanicAsian     FM
#
# ...
